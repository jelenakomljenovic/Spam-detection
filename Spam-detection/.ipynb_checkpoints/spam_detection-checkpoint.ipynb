# %% [markdown]
# # Spam detection using a multi-layer perceptron

# %% [markdown]
# #### **Import libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from wordcloud import WordCloud
from sklearn.metrics import classification_report, confusion_matrix, precision_score

# %% [markdown]
# #### **Data Loading**

# %%
df = pd.read_csv('emails.csv')
df.shape
# Out:
# (450, 2)

# %%
df.head()
# Out:
#                                                email  spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   email   450 non-null    object
#  1   spam    450 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 7.2+ KB

# %%
X = df['email']

# %%
Y = df['spam']

# %% [markdown]
# #### **Data Cleaning**

# %%
df.isnull().sum()
# Out:
# email    0
# spam     0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# #### **Data Visualization**

# %%
Y.value_counts()
# Out:
# spam
# 0    226
# 1    224
# Name: count, dtype: int64

# %%
colors = ['#BBD2EC', '#A7AED3']
plt.pie(Y.value_counts(), labels=['non-spam','spam'], autopct="%0.2f", colors=colors)
plt.show()
#plt.savefig("spam.png")

# %%
wc = WordCloud(width=500,height=500,min_font_size=10,background_color='white')

spam_words = wc.generate(df[Y == 1]['email'].str.cat(sep=" "))
plt.figure(figsize=(15,6))
plt.imshow(spam_words)
#plt.savefig("spam_words.png")

# %%
non_spam_words = wc.generate(df[Y == 0]['email'].str.cat(sep=" "))
plt.figure(figsize=(15,6))
plt.imshow(non_spam_words)
#plt.savefig("non_spam_words.png")

# %% [markdown]
# #### **TF-IDF matrix**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tf = TfidfVectorizer(max_df=0.8) # ignore terms that appear in more than 80% of the documents
message = tf.fit_transform(X)

# %%
tf.get_feature_names_out()
# Out:
# array(['00', '000', '0000', ..., 'zwlaszcza', 'zxghlajf', 'zzzz'],
#       dtype=object)

# %% [markdown]
# #### **CountVectorizer**

# %%
# from sklearn.feature_extraction.text import CountVectorizer

# cv = CountVectorizer()
# message = cv.fit_transform(X)
# cv.get_feature_names_out()

# %% [markdown]
# #### **Data Splitting** (test and train)

# %%
X_train, X_test, y_train, y_test = train_test_split(message, Y, test_size=0.20, random_state=0)

# %% [markdown]
# #### **MLP**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import regularizers

# %%
model = Sequential()
model.add(Dense(input_dim=X_train.shape[1], units=100, activation='relu'))
# model.add(Dense(units=64, activation='relu'))
# model.add(Dense(units=128, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_49"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_138 (Dense)           (None, 100)               1126800
#
#  dense_139 (Dense)           (None, 1)                 101
#
# =================================================================
# Total params: 1126901 (4.30 MB)
# Trainable params: 1126901 (4.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train.toarray(), y_train, batch_size=64, epochs=4, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/4
# 5/5 [==============================] - 1s 90ms/step - loss: 0.6839 - accuracy: 0.7222 - val_loss: 0.6590 - val_accuracy: 0.9167
# Epoch 2/4
# 5/5 [==============================] - 0s 43ms/step - loss: 0.6257 - accuracy: 0.9931 - val_loss: 0.6119 - val_accuracy: 0.9583
# Epoch 3/4
# 5/5 [==============================] - 0s 53ms/step - loss: 0.5545 - accuracy: 1.0000 - val_loss: 0.5597 - val_accuracy: 0.9583
# Epoch 4/4
# 5/5 [==============================] - 0s 39ms/step - loss: 0.4819 - accuracy: 1.0000 - val_loss: 0.5094 - val_accuracy: 0.9583

# %%
epochs = history.epoch
plt.plot(epochs, history.history['loss'], label="training set") # blue
plt.plot(epochs, history.history['val_loss'], label="validation set") #orange
plt.title('loss')
plt.legend()
plt.savefig("loss.png")

# %%
plt.plot(epochs, history.history['accuracy'], label="training set") #blue
plt.plot(epochs, history.history['val_accuracy'], label="validation set") #orange
plt.title('accuracy')
plt.savefig("accuracy.png")
plt.legend()

# %%
model.evaluate(X_test.toarray(), y_test, batch_size=64)
# Out:
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5141 - accuracy: 0.9667
# [0.5141165852546692, 0.9666666388511658]

# %%
y_pred = model.predict(X_test.toarray())
# Out:
# 3/3 [==============================] - 0s 6ms/step

# %% [markdown]
# #### **Metrics**

# %%
y_pred_new = [int(not(i<0.5)) for i in y_pred]

cm =confusion_matrix(y_test, y_pred_new)
plt.figure(dpi=100)
sns.heatmap(cm, annot=True)
plt.title("Confusion matrix")
plt.show()

# %%
print(classification_report(y_test, y_pred_new))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.93      0.97        45
#            1       0.94      1.00      0.97        45
#
#     accuracy                           0.97        90
#    macro avg       0.97      0.97      0.97        90
# weighted avg       0.97      0.97      0.97        90

# %%
precision_score(y_test, y_pred_new)
# Out:
# 0.9375
